# %%
import cellfinder
print(cellfinder.__file__)
# Out:
# C:\Users\sasip\GSoC\cellfinder\cellfinder\__init__.py

# %%
from cellfinder.core import detect
print(detect.__file__)
# Out:
# C:\Users\sasip\GSoC\cellfinder\cellfinder\core\detect\__init__.py
